# %%
import pandas as pd

dir(pd.Series)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
s = set([i for i in dir(pd.Series) if not i.startswith("_")])
d = set([i for i in dir(pd.DataFrame) if not i.startswith("_")])

count = 0

for i in (s-d):
    count += 1
    print(i, end=', ')
    if (count % 4 == 0):
        print()
# Out:
# cat, between, repeat, is_monotonic,
# str, tolist, dtype, item,
# hasnans, is_unique, unique, ravel,
# autocorr, argsort, array, rdivmod,
# argmin, is_monotonic_increasing, argmax, factorize,
# nbytes, dt, map, is_monotonic_decreasing,
# searchsorted, to_list, to_frame, name,
# divmod, view,

# %%
s = set([i for i in dir(pd.Series) if not i.startswith("_")])
d = set([i for i in dir(pd.DataFrame) if not i.startswith("_")])

count = 0

for i in (d-s):
    count += 1
    print(i, end=', ')
    if (count % 4 == 0):
        print()
# Out:
# to_records, style, to_html, lookup,
# eval, info, from_records, to_stata,
# applymap, boxplot, join, select_dtypes,
# stack, insert, itertuples, to_feather,
# pivot_table, from_dict, merge, to_parquet,
# set_index, to_gbq, melt, columns,
# pivot, query, iterrows, assign,
# corrwith,

# %%
s = set([i for i in dir(pd.Series) if not i.startswith("_")])
d = set([i for i in dir(pd.DataFrame) if not i.startswith("_")])

count = 0

for i in (d & s):
    count += 1
    print(i, end=', ')
    if (count % 4 == 0):
        print()
# Out:
# rdiv, le, reindex_like, max,
# tail, ge, shape, copy,
# equals, last_valid_index, bfill, tz_localize,
# rank, explode, dot, mad,
# duplicated, to_sql, take, div,
# xs, skew, mul, any,
# slice_shift, lt, head, align,
# divide, items, replace, nsmallest,
# reindex, ne, rtruediv, get,
# pct_change, tshift, backfill, asfreq,
# std, add_prefix, T, rename,
# mode, index, iteritems, fillna,
# cummax, combine, droplevel, empty,
# update, sort_values, drop, iloc,
# isna, rolling, isin, gt,
# interpolate, rpow, cumsum, flags,
# ffill, subtract, to_latex, bool,
# ndim, round, clip, pop,
# describe, truediv, nlargest, multiply,
# reorder_levels, combine_first, swapaxes, values,
# cumprod, infer_objects, pow, rmod,
# to_xarray, sparse, idxmin, set_axis,
# sample, keys, mask, where,
# floordiv, hist, truncate, to_clipboard,
# squeeze, nunique, sum, aggregate,
# to_excel, kurtosis, min, eq,
# to_numpy, add, product, resample,
# rename_axis, median, cummin, plot,
# ...

# %%
df_f = pd.read_csv('./handinpandas/data/series_dataframe.csv', usecols=['Member', 'Series', 'DataFrame'],encoding='euc-kr')
df_f
# Out:
#          Member      Series   DataFrame
# 0             T           T           T
# 1           abs         abs         abs
# 2           add         add         add
# 3    add_prefix  add_prefix  add_prefix
# 4    add_suffix  add_suffix  add_suffix
# ..          ...         ...         ...
# 259      values      values      values
# 260         var         var         var
# 261        view        view         NaN
# 262       where       where       where
# 263          xs          xs          xs
#
# [264 rows x 3 columns]

# %%
import numpy as np
s = pd.Series(np.random.randint(10))
s
# Out:
# 0    3
# dtype: int64

# %%
np.random.randint(5, size=(2,2,5))
# Out:
# array([[[0, 0, 0, 2, 0],
#         [2, 3, 0, 0, 4]],
#
#        [[2, 4, 1, 0, 2],
#         [4, 0, 2, 3, 1]]])

# %%
np.random.randn(5)
# Out:
# array([ 0.2326861 ,  1.17939637,  0.14589516, -0.20509005, -1.1465278 ])

# %%
#Seires를 열로 넣기
s1 = pd.Series([1,2,3,4], name='s1')
s2 = pd.Series(['a', 'b', 'c', 'd'], name='s1')

df = pd.DataFrame({'s1':s1, 's2':s2})

#Series를 행으로 넣기
# df = pd.DataFrame([s1, s2])
df
# Out:
#    s1 s2
# 0   1  a
# 1   2  b
# 2   3  c
# 3   4  d

# %%
df = pd.DataFrame(df, columns=['s1', 's3'])
df
# Out:
#    s1  s3
# 0   1 NaN
# 1   2 NaN
# 2   3 NaN
# 3   4 NaN

# %%
import pandas as pd

names = ['bob', 'jessica']
births = [968, 155]
BabyDataSet = list(zip(names, births))


df = pd.DataFrame(BabyDataSet, columns=['names', 'births'])
df
# Out:
#      names  births
# 0      bob     968
# 1  jessica     155

# %%
df.values
# Out:
# array([['bob', 968],
#        ['jessica', 155]], dtype=object)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=2, step=1),
#  Index(['names', 'births'], dtype='object')]

# %%
s = set(pd.Series._dict_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e4717a278a98> in <module>
# ----> 1 s = set(pd.Series._dict_)
#
# AttributeError: type object 'Series' has no attribute '_dict_'

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = df.loc[((df.pclass == 3) & (df.who == 'man')), ['fare']]
df
# Out:
#         fare
# 0     7.2500
# 4     8.0500
# 5     8.4583
# 12    8.0500
# 13   31.2750
# ..       ...
# 877   7.8958
# 878   7.8958
# 881   7.8958
# 884   7.0500
# 890   7.7500
#
# [319 rows x 1 columns]

# %%
ser1 = df['sex']

# %%
ser1[100]
# Out:
# 'female'

# %%
df_slice = df[10:20]
df_slice
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 10  child       False    G  Southampton   yes  False
# ...

# %%
df[['survived','fare']][0:1]
# Out:
#    survived  fare
# 0         0  7.25

# %%
df[~(df.sex == 'male')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.__getitem__(slice(10,20)).head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
# 12         0       3    male  20.0      0      0   8.0500        S  Third
# 13         0       3    male  39.0      1      5  31.2750        S  Third
# 14         0       3  female  14.0      0      0   7.8542        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True

# %%
df[10:20]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 10  child       False    G  Southampton   yes  False
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna(axis=1).isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# sibsp         0
# parch         0
# fare          0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %%
a = ((df.sex == 'male') & (df.age >= 25))
df = df[a]
df
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 13          0       3  male  39.0      1      5  31.2750        S   Third
# 20          0       2  male  35.0      0      0  26.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
df_class_first = df[df.pclass == 3]

# %%
df_class_first['pclass']
# Out:
# 4      3
# 13     3
# 57     3
# 69     3
# 73     3
#       ..
# 870    3
# 873    3
# 881    3
# 884    3
# 890    3
# Name: pclass, Length: 135, dtype: int64

# %%
import seaborn as sns
df = sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.iloc[0:1, 1:2]
# Out:
#      cut
# 0  Ideal

# %%
df.loc[0, ['cut','x']]
# Out:
# cut    Ideal
# x       3.95
# Name: 0, dtype: object

# %%
df.xs(0)
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
import seaborn as sns
diamond = sns.load_dataset('diamonds')


set_i = diamond.set_index('color')
set_i
# Out:
#        carat        cut clarity  depth  table  price     x     y     z
# color
# E       0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...     ...    ...    ...    ...   ...   ...   ...
# D       0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# D       0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# D       0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# H       0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# D       0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
import os 
import pandas as pd
os.chdir('C:\\Users\\doch2\\handinpandas\\data')

# %%
movies = pd.read_csv('./movies.csv', usecols = ['Film', 'Year'])

# %%
movies_add = pd.read_csv('./movies.csv')

# %%
movies['has_seen'] = 0

# %%
movies
# Out:
#                                   Film  Year  has_seen
# 0           Zack and Miri Make a Porno  2008         0
# 1                      Youth in Revolt  2010         0
# 2   You Will Meet a Tall Dark Stranger  2010         0
# 3                         When in Rome  2010         0
# 4                What Happens in Vegas  2008         0
# ..                                 ...   ...       ...
# 72                 Across the Universe  2007         0
# 73                       A Serious Man  2009         0
# 74                  A Dangerous Method  2011         0
# 75                          27 Dresses  2008         0
# 76                (500) Days of Summer  2009         0
#
# [77 rows x 3 columns]

# %%
movies_add.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
movies.columns.get_loc('has_seen')
# Out:
# 2

# %%
movies.insert(movies.columns.get_loc('has_seen')+1, 'a', 1)

# %%
movies
# Out:
#                                   Film  Year  has_seen  a
# 0           Zack and Miri Make a Porno  2008         0  1
# 1                      Youth in Revolt  2010         0  1
# 2   You Will Meet a Tall Dark Stranger  2010         0  1
# 3                         When in Rome  2010         0  1
# 4                What Happens in Vegas  2008         0  1
# ..                                 ...   ...       ... ..
# 72                 Across the Universe  2007         0  1
# 73                       A Serious Man  2009         0  1
# 74                  A Dangerous Method  2011         0  1
# 75                          27 Dresses  2008         0  1
# 76                (500) Days of Summer  2009         0  1
#
# [77 rows x 4 columns]

# %%
a = movies['a']
a
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 72    1
# 73    1
# 74    1
# 75    1
# 76    1
# Name: a, Length: 77, dtype: int64

# %%
a.put(0, 9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-2f6b703bc6ea> in <module>
# ----> 1 a.put(0, 9)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'put'

# %%
movies_del = pd.read_csv('./movies.csv')

# %%
movies_del.shape
# Out:
# (77, 8)

# %%
movies_del.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
movies_del.drop('Rotten Tomatoes %', axis=1)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability Worldwide Gross  Year
# ...

# %%
mvies_del2 = movies_del.drop([0,1,2,3,4], axis=0)
mvies_del2
# Out:
#                     Film      Genre       Lead Studio  Audience score %  \
# 5    Water For Elephants      Drama  20th Century Fox                72
# 6                 WALL-E  Animation            Disney                89
# 7               Waitress    Romance       Independent                67
# 8    Waiting For Forever    Romance       Independent                53
# 9        Valentine's Day     Comedy      Warner Bros.                54
# ..                   ...        ...               ...               ...
# 72   Across the Universe    romance       Independent                84
# 73         A Serious Man      Drama         Universal                64
# 74    A Dangerous Method      Drama       Independent                89
# 75            27 Dresses     Comedy               Fox                71
# 76  (500) Days of Summer     comedy               Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
movies_str = pd.read_csv('./korea_movie_list.csv', engine='python')

# %%
movies_str.columns
# Out:
# Index(['movie_code', 'title', 'title_Eng', 'show_time', 'produce_year',
#        'open_date', 'produce_state', 'type', 'nation', 'genre', 'director',
#        'actor', 'show_type', 'watch_grade'],
#       dtype='object')

# %%
movies_str
# Out:
#       movie_code                        title  \
# 0       20185801                   �ҷο� ���ϵ�
# 1       20187649                ������ ������
# 2       20187641  ������ ���󿡸�: ������ ������
# 3       20187427    ��Ž�� �ڳ� : ������ ������
# 4       20173732                  ��Ƴ��� ����
# ...          ...                          ...
# 2822    20168162                 ����ȣ���� �谨
# 2823    20167543                 ���ҽ��� 2017
# 2824    20168153              ������ΰ� ��а���
# 2825    20168186           �ҷ����� ȲȦ�� �Ը���
# 2826    20168152             ��Ӹ� ���ϸ�������
#
#                                               title_Eng  show_time  \
# 0                                      The Hollow Child       88.0
# 1                                          Glass Coffin       75.0
# 2                                                   NaN      107.0
# 3                    Detective Conan: Zero the Enforcer      110.0
# 4                                            Last Child      123.0
# ...

# %%
s = str('가을')
s
# Out:
# '가을'

# %%
s.find('을')
# Out:
# 1

# %%
si = str('찬혁')

# %%
type(si)
# Out:
# str

# %%
si = '찬혁'
type(si)
# Out:
# str

# %%
si.find('을')
# Out:
# -1

# %%
import numpy as np

# %%
# Out:
# 0    [가, 나, 다]
# 1    [라, 마, 바]
# 2          NaN
# 3    [사, 아, 자]
# dtype: object

# %%
# Out:
# 0      나
# 1      마
# 2    NaN
# 3      아
# dtype: object

# %%
ss.str.split('_', expand=True)
# Out:
#      0    1    2
# 0    가    나    다
# 1    라    마    바
# 2  NaN  NaN  NaN
# 3    사    아    자

# %%
# Out:
#      0    1
# 0    가  나_다
# 1    라  마_바
# 2  NaN  NaN
# 3    사  아_자

# %%
# Out:
#      0    1
# 0  가_나    다
# 1  라_마    바
# 2  NaN  NaN
# 3  사_아    자

# %%
count = 0

for i in op_eq_list:
    try:
        if type(pd.Series.__dict__[i]) == types.FunctionType:
            print(i, end=', ')
            count += 1
        if count % 7 :
            print()
            
    except Exception as e:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-089150ac7214> in <module>
#       1 count = 0
#       2
# ----> 3 for i in op_eq_list:
#       4     try:
#       5         if type(pd.Series.__dict__[i]) == types.FunctionType:
#
# NameError: name 'op_eq_list' is not defined

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
nan_df = df['deck'].value_counts(dropna=False) # dropna 를 False로 해야 누락 갯수를 알 수 있음

df.head().isnull() # isnull()은 원소가 Null 데이터나 NaN 데이터일 경우 해당 원소를 True로 반환하며 유효 데이터일경우 False를 반환
df.head().notnull() #isnull의 반대

df.isnull().sum(axis= 0)

ndf = df.dropna(axis=1, thresh=445) # thresh 옵션을 사용해서 누락 데이터가 전체 데이터 개수의 절반이 넘는 열을 제거
ndf.columns
ndf

ndf2 = ndf.dropna(subset=['age'], how='any', axis=0)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['sex'].value_counts(normalize=True).head()
# Out:
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
df['fare'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Name: fare, Length: 891, dtype: bool

# %%
df['fare'].unique
# Out:
# <bound method Series.unique of 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64>

# %%
df['fare'].sort_values(ascending=False)
# Out:
# 258    512.3292
# 737    512.3292
# 679    512.3292
# 88     263.0000
# 27     263.0000
#          ...
# 633      0.0000
# 413      0.0000
# 822      0.0000
# 732      0.0000
# 674      0.0000
# Name: fare, Length: 891, dtype: float64

# %%
a = [1,2,3]
s1 = pd.Series([10, 20, 30], index=list('abc'))

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
flight_route_info = pd.read_csv('./flight_route_info.csv', encoding='cp949')

# %%
flight_route_info.columns
# Out:
# Index(['노선명', '항공사', '출발지', '출발국', '도착지', '도착국', '검수', '2016.6', '2018.5',
#        '상태', '비고', '운항 횟수', '운항_2016', '운항_2017', '운항_2018', '운항_2016.12',
#        '운항_2017.1', '운항_2017.2', '운항_2017.12', '운항_2018.1', '운항_2018.2',
#        '운항_2016겨울', '운항_2017겨울', '운항_겨울 총합', '운항_2017.3', '운항_2017.4',
#        '운항_2017.5', '운항_2018.3', '운항_2018.4', '운항_2018.5', '운항_2017봄',
#        '운항_2018봄', '운항_봄 총합', '운항_2016.6', '운항_2016.7', '운항_2016.8',
#        '운항_2017.6', '운항_2017.7', '운항_2017.8', '운항_2016여름', '운항_2017여름',
#        '운항_여름 총합', '운항_2016.9', '운항_2016.10', '운항_2016.11', '운항_2017.9',
#        '운항_2017.10', '운항_2017.11', '운항_2016가을', '운항_2017가을', '운항_가을 총합', '운송량',
#        '운송량_2016', '운송량_2017', '운송량_2018', '운송량_2016.12', '운송량_2017.1',
#        '운송량_2017.2', '운송량_2017.12', '운송량_2018.1', '운송량_2018.2', '운송량_2016겨울',
#        '운송량_2017겨울', '운송량_겨울 총합', '운송량_2017.3', '운송량_2017.4', '운송량_2017.5',
#        '운송량_2018.3', '운송량_2018.4', '운송량_2018.5', '운송량_2017봄', '운송량_2018봄',
# ...

# %%
flight_route_info
# Out:
#         노선명        항공사  출발지  출발국  도착지  도착국 검수 2016.6 2018.5  상태  ...  \
# 0     7J105  Tajik Air  DYU  TJK  IKA  IRI  O      O      O  완료  ...
# 1     7J117  Tajik Air  DYU  TJK  DEL  IND  O      O      O  완료  ...
# 2    7J4801  Tajik Air  DYU  TJK  SVX  RUS  O      O      O  완료  ...
# 3    7J4805  Tajik Air  DYU  TJK  SGC  RUS  O      O      O  완료  ...
# 4    7J4849  Tajik Air  DYU  TJK  FRU  KGZ  O      O      O  완료  ...
# ..      ...        ...  ...  ...  ...  ... ..    ...    ...  ..  ...
# 672   ZM559  Air Manas  FRU  KGZ  DME  RUS  O      O      O  완료  ...
# 673   ZM561  Air Manas  FRU  KGZ  DME  RUS  O      O      O  완료  ...
# 674  ZM5610  Air Manas  FRU  KGZ  DME  RUS  O      O      O  완료  ...
# 675   ZM641  Air Manas  FRU  KGZ  DME  RUS  O      O      O  완료  ...
# 676   ZM809  Air Manas  FRU  KGZ  KHG  CHN  O      O      O  완료  ...
#
#     운송량_여름 총합  운송량_2016.9  운송량_2016.10  운송량_2016.11  운송량_2017.9  운송량_2017.10  \
# ...

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')

#3
df[df['sex']=='male']

#4
df = df[(df.sex=='male') & (df.alive=='yes')]

#5
a = ((df.sex == 'male') & (df.age >= 25))
df = df[a]
df
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 21          1       2  male  34.0      0      0   13.0000        S  Second
# 23          1       1  male  28.0      0      0   35.5000        S   First
# 74          1       3  male  32.0      0      0   56.4958        S   Third
# 81          1       3  male  29.0      0      0    9.5000        S   Third
# 146         1       3  male  27.0      0      0    7.7958        S   Third
# 187         1       1  male  45.0      0      0   26.5500        S   First
# 207         1       3  male  26.0      0      0   18.7875        C   Third
# 209         1       1  male  40.0      0      0   31.0000        C   First
# 224         1       1  male  38.0      1      0   90.0000        S   First
# 248         1       1  male  37.0      1      1   52.5542        S   First
# 267         1       3  male  25.0      1      0    7.7750        S   Third
# ...

# %%
#컬럼명 필터 : 정규표현식
df.filter(regex = '\d')
# Out:
# Empty DataFrame
# Columns: []
# Index: [21, 23, 74, 81, 146, 187, 207, 209, 224, 248, 267, 271, 286, 288, 338, 370, 390, 400, 414, 429, 430, 447, 449, 453, 455, 460, 484, 509, 510, 512, 543, 569, 570, 572, 579, 587, 599, 604, 607, 621, 630, 632, 645, 647, 660, 673, 679, 681, 690, 701, 707, 712, 724, 737, 744, 804, 821, 838, 857, 889]

# %%
import numpy as np
s = pd.Series([0, 1, np.nan, 3])

s.fillna(method='bfill')
s.fillna(method='backfill')
# Out:
# 0    0.0
# 1    1.0
# 2    3.0
# 3    3.0
# dtype: float64
